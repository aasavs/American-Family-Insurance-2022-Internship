# %%
import pandas as pd

# %%
litigation_data = pd.read_csv("litigation_anomolies.csv")
payment_data = pd.read_csv("Claims Pay Data July 1st.csv")
# Out:
# C:\Users\TWILLI16\AppData\Local\Temp\ipykernel_14196\3597489710.py:2: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   payment_data = pd.read_csv("Claims Pay Data July 1st.csv")

# %%
set(litigation_data["close_datetime"])
# Out:
# {nan,
#  'Jan 14, 2022, 10:09:34 AM',
#  'Dec 13, 2021, 11:01:15 AM',
#  'Feb 18, 2022, 4:28:47 PM',
#  'Jan 18, 2022, 4:20:19 PM',
#  'Jun 22, 2022, 8:50:41 AM',
#  'Feb 25, 2022, 7:48:30 AM',
#  'Oct 2, 2020, 11:26:08 AM',
#  'Apr 27, 2020, 6:59:51 PM',
#  'Aug 24, 2020, 10:17:55 AM',
#  'Jul 13, 2022, 9:01:35 AM',
#  'Apr 21, 2022, 2:18:44 PM',
#  'Nov 5, 2020, 5:29:57 PM',
#  'Oct 12, 2021, 4:47:45 PM',
#  'Jan 24, 2022, 10:25:35 AM',
#  'Apr 4, 2022, 12:45:35 PM',
#  'Mar 30, 2022, 3:16:39 PM',
#  'Feb 23, 2022, 11:13:54 AM',
#  'Jan 10, 2022, 7:08:13 PM',
#  'May 26, 2022, 1:27:37 PM',
#  'Dec 20, 2021, 11:07:20 AM',
#  'Apr 5, 2021, 11:19:17 AM',
#  'May 18, 2022, 9:52:06 AM',
#  'Apr 8, 2022, 2:10:32 PM',
#  'Jun 9, 2022, 8:33:30 AM',
#  'Sep 9, 2020, 2:44:14 PM',
#  'Nov 24, 2021, 10:55:23 AM',
#  'Jan 18, 2022, 3:20:56 PM',
#  'Jan 19, 2022, 3:07:09 PM',
#  'May 20, 2021, 2:34:23 PM',
#  'Apr 20, 2022, 3:18:44 PM',
#  'May 12, 2022, 7:55:14 AM',
# ...

# %%
set(payment_data["issue_date"])
# Out:
# {'1-Jul-22',
#  '1-Jun-22',
#  '10-Jun-22',
#  '11-Jun-22',
#  '12-Jun-22',
#  '13-Jun-22',
#  '14-Jun-22',
#  '15-Jun-22',
#  '16-Jun-22',
#  '17-Jun-22',
#  '18-Jun-22',
#  '19-Jun-22',
#  '2-Jun-22',
#  '20-Jun-22',
#  '21-Jun-22',
#  '22-Jun-22',
#  '23-Jun-22',
#  '24-Jun-22',
#  '25-Jun-22',
#  '26-Jun-22',
#  '27-Jun-22',
#  '28-Jun-22',
#  '29-Jun-22',
#  '3-Jun-22',
#  '30-Jun-22',
#  '4-Jun-22',
#  '5-Jun-22',
#  '6-Jun-22',
#  '7-Jun-22',
#  '8-Jun-22',
#  '9-Jun-22'}

# %%
pd.merge(litigation_data,payment_data,how = "left",on = ["claim_number","claim_number"])
# Out:
#        claim_number claim_status            close_datetime  \
# 0     MS-001-217089       Closed  Jul 6, 2022, 12:37:12 PM
# 1     MS-001-213067       Closed  Feb 17, 2022, 6:38:47 AM
# 2     MS-001-209767       Closed  Jun 22, 2022, 7:18:16 AM
# 3     MS-001-208044       Closed  Mar 17, 2022, 6:28:23 AM
# 4     MS-001-208044       Closed  Mar 17, 2022, 6:28:23 AM
# ...             ...          ...                       ...
# 2415  00-035-025973       Closed   Jun 9, 2022, 1:15:11 PM
# 2416  00-035-018380       Closed  Apr 28, 2020, 9:49:20 AM
# 2417  00-035-018380       Closed  Aug 16, 2018, 9:49:53 AM
# 2418  00-035-018380       Closed  Aug 16, 2018, 9:49:42 AM
# 2419  00-021-060721       Closed   Mar 2, 2022, 2:29:28 PM
#
#       converted_record_ind  litigation_claim_ind    litigation_status  \
# 0                        1                     1  Litigation complete
# 1                        1                     1  Litigation complete
# ...
